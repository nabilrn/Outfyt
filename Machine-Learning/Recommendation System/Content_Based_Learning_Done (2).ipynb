# %%
import os
import pandas as pd
import numpy as np
import joblib
import re
#from flask import Flask, request, jsonify
#from flask_cors import CORS
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class LikableOutfitRecommender:
    def __init__(self, csv_path='styles_new.csv', sep=';', model_path='/content/drive/MyDrive/outfit_recommender_model.joblib'):
        self.skin_color_matches = {
            'Summer': [
                'Navy Blue', 'Pink', 'Lavender',
                'Purple', 'Blue', 'Teal',
                'White', 'Grey', 'Sea Green',
                'Turquoise Blue', 'Green'
            ],
            'Fall': [
                'Burgundy', 'Brown', 'Olive',
                'Maroon', 'Bronze', 'Copper',
                'Gold', 'Red', 'Orange'
            ],
            'Winter': [
                'Black', 'White', 'Grey',
                'Navy Blue', 'Red', 'Purple',
                'Burgundy', 'Silver', 'Teal'
            ],
            'Spring': [
                'Green', 'Lime Green', 'Yellow',
                'Pink', 'Light Blue', 'Turquoise',
                'Orange', 'Maroon'
            ]
        }

        self.subcategory_likes = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
        self.user_recommendations = defaultdict(lambda: defaultdict(list))
        self.user_likes = defaultdict(lambda: defaultdict(list))

        self.model_path = model_path

        # Check if a pre-trained model exists
        if os.path.exists(model_path):
            self.load_model()
        else:
            # Initialize from scratch and train
            self.data = None
            self.label_encoders = {}
            self.tfidf = TfidfVectorizer(stop_words='english')
            self.scaler = MinMaxScaler()

            # Initialize recommender with data
            df = pd.read_csv(csv_path, sep=sep)
            df.dropna(inplace=True)

            # Ensure correct data types
            df['productDisplayName'] = df['productDisplayName'].astype(str)
            df['id'] = df['id'].astype(str)
            df['gender'] = df['gender'].astype(str)
            df['baseColour'] = df['baseColour'].astype(str)
            df['usage'] = df['usage'].astype(str)
            df['season'] = df['season'].astype(str)

            # Fit the recommender with the loaded data
            self.fit(df)

            # Save the trained model
            self.save_model()

    def save_model(self):
        """
        Save the trained model components to a file
        """
        model_components = {
            'data': self.data,
            'label_encoders': self.label_encoders,
            'tfidf': self.tfidf,
            'scaler': self.scaler,
            'feature_matrix': self.feature_matrix,
            'similarity_matrix': self.similarity_matrix
        }

        joblib.dump(model_components, self.model_path)
        print(f"Model saved to {self.model_path}")

    def load_model(self):
        """
        Load pre-trained model components from a file
        """
        model_components = joblib.load(self.model_path)

        self.data = model_components['data']
        self.label_encoders = model_components['label_encoders']
        self.tfidf = model_components['tfidf']
        self.scaler = model_components['scaler']
        self.feature_matrix = model_components['feature_matrix']
        self.similarity_matrix = model_components['similarity_matrix']

        print(f"Model loaded from {self.model_path}")

    def fit(self, data, feature_weights=None):
        self.data = data.copy().reset_index(drop=True)

        categorical_features = ['gender', 'masterCategory', 'subCategory', 'articleType',
                               'baseColour', 'season', 'usage']

        if feature_weights is None:
            feature_weights = {f: 1.0 for f in categorical_features}

        encoded_features_list = []
        for feature in categorical_features:
            if feature in self.data.columns:
                self.label_encoders[feature] = LabelEncoder()
                encoded_feature = self.label_encoders[feature].fit_transform(self.data[feature])
                encoded_features_list.append(encoded_feature.reshape(-1, 1))

        encoded_features = np.hstack(encoded_features_list)
        encoded_features_scaled = self.scaler.fit_transform(encoded_features) * [feature_weights[f] for f in categorical_features]

        self.data['clean_name'] = self.data['productDisplayName'].apply(self.preprocess_text)
        text_features = self.tfidf.fit_transform(self.data['clean_name'])

        self.feature_matrix = np.hstack((encoded_features_scaled, text_features.toarray()))

        self.similarity_matrix = cosine_similarity(self.feature_matrix)

        return self

    def preprocess_text(self, text):
        text = str(text).lower()
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        return text

    def _get_input_key(self, skin_tone, gender, usage, season):
        return f"{skin_tone}_{gender}_{usage}_{season}"

    def add_like(self, user_id, product_name, subcategory, skin_tone, gender, usage, season, rating=1):
        input_key = self._get_input_key(skin_tone, gender, usage, season)

        product = self.data[self.data['productDisplayName'] == product_name]
        if len(product) == 0:
            print(f"Product not found: {product_name}")
            return

        item_id = product.iloc[0]['id']
        self.subcategory_likes[subcategory][input_key][item_id] += rating
        self.user_likes[user_id][subcategory].append(item_id)

    def get_recommendations_by_subcategory(self, user_id, skin_tone, gender, usage, season, subcategory, n=4):
        input_key = self._get_input_key(skin_tone, gender, usage, season)
        recommended_colors = self.skin_color_matches.get(skin_tone, [])

        mask = (
            (self.data['subCategory'] == subcategory) &
            (self.data['gender'] == gender) &
            (self.data['usage'] == usage) &
            (self.data['season'] == season) &
            (self.data['baseColour'].isin(recommended_colors))
        )

        filtered_data = self.data[mask].reset_index(drop=True)

        if len(filtered_data) == 0:
            return pd.DataFrame()

        mask_indices = np.where(mask)[0]
        filtered_similarities = self.similarity_matrix[mask_indices][:, mask_indices]
        base_scores = filtered_similarities.mean(axis=0)

        like_scores = np.zeros(len(filtered_data))

        for i, (_, row) in enumerate(filtered_data.iterrows()):
            likes = self.subcategory_likes[subcategory][input_key][row['id']]
            like_scores[i] = likes

        if like_scores.max() > 0:
            like_scores = like_scores / like_scores.max()

        n = min(n, len(filtered_data))
        top_indices = np.argsort(base_scores)[::-1][:n]

        item_sims = filtered_similarities[top_indices][:,top_indices]
        diversity_penalty = item_sims.mean(axis=1)

        final_scores = 0.6 * base_scores[top_indices] + 0.3 * like_scores[top_indices] - 0.1 * diversity_penalty + 0.1 * np.random.random(n)

        top_indices = top_indices[np.argsort(final_scores)[::-1]]

        recommendations = filtered_data.iloc[top_indices][[
            'id', 'productDisplayName', 'gender', 'baseColour', 'usage',
            'season', 'masterCategory', 'subCategory'
        ]].copy()
        recommendations['score'] = final_scores

        self.user_recommendations[user_id][subcategory].extend(recommendations['id'].tolist())

        return recommendations

    def get_complete_outfit(self, user_id, skin_tone, gender, usage, season):
        outfit_recommendations = {
            'Recommended Colors': self.skin_color_matches[skin_tone],
            'Outfit': {},
            'Input': {
                'skin_tone': skin_tone,
                'gender': gender,
                'usage': usage,
                'season': season
            }
        }

        subcategories = ['Accessories', 'Headwear', 'Bottomwear', 'Topwear', 'Flip Flops', 'Sandal', 'Shoes', 'Sports Equipment']

        for subcat in subcategories:
            recommendations = self.get_recommendations_by_subcategory(
                user_id, skin_tone, gender, usage, season, subcat
            )
            if not recommendations.empty:
                outfit_recommendations['Outfit'][subcat] = recommendations.to_dict('records')

        return outfit_recommendations

# %%
def print_outfit_recommendations(outfit_recommendations, user_id):
    print(f"\nRecommendations for User {user_id}:")
    print(f"Input parameters: {outfit_recommendations['Input']}")
    print("\nRecommended Colors:", ", ".join(outfit_recommendations['Recommended Colors']))

    print("\nRecommended Outfit:")
    for subcategory, items in outfit_recommendations['Outfit'].items():
        print(f"\n{subcategory}:")
        for item in items:
            print(f"- {item['productDisplayName']} ({item['baseColour']})")
            print(f"  Score: {item['score']:.2f}")
            print(f"  To like this item, use:")
            print(f"  recommender.add_like('{user_id}', '{item['productDisplayName']}', '{subcategory}', **input_params)")

# %%
recommender = LikableOutfitRecommender('/content/styles_new.csv')
# Out:
# Model saved to /content/drive/MyDrive/outfit_recommender_model.joblib

# %%
file_size = os.path.getsize('/content/drive/MyDrive/outfit_recommender_model.joblib') / (1024 * 1024)  # Dalam MB
print(f"Ukuran file model: {file_size:.2f} MB")
# Out:
# Ukuran file model: 12118.95 MB

# %%
print(os.path.exists('/content/drive/MyDrive/outfit_recommender_model.joblib'))
# Out:
# True

# %%
users = ['user1', 'user2', 'user3']
input_params = {
    'skin_tone': 'Fair',
    'gender': 'Men',
    'usage': 'Casual',
    'season': 'Summer'
}

# %%
outfit = recommender.get_complete_outfit('user1', **input_params)
print_outfit_recommendations(outfit, 'user1')
# Out:
# Recommendations for User user1:
# Input parameters: {'skin_tone': 'Fair', 'gender': 'Men', 'usage': 'Casual', 'season': 'Summer'}
#
# Recommended Colors: Navy Blue, Pink, Lavender, Purple, Blue, Teal, Burgundy, Red, White, Grey, Black, Turquoise Blue, Green, Sea Green
#
# Recommended Outfit:
#
# Accessories:
# - Cabarelli Men Accessory Gift Set (Black)
#   Score: 0.32
#   To like this item, use:
#   recommender.add_like('user1', 'Cabarelli Men Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Black Accessory Gift Set (Black)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user1', 'Cabarelli Men Black Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Accessory Gift Set (Black)
#   Score: 0.41
#   To like this item, use:
#   recommender.add_like('user1', 'Cabarelli Men Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Black Accessory Gift Set (Black)
#   Score: 0.37
#   To like this item, use:
#   recommender.add_like('user1', 'Cabarelli Men Black Accessory Gift Set', 'Accessories', **input_params)
#
# Headwear:
# - Flying Machine Men Green Cap (Green)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user1', 'Flying Machine Men Green Cap', 'Headwear', **input_params)
# - Flying Machine Men Navy Blue Cap (Navy Blue)
#   Score: 0.41
#   To like this item, use:
#   recommender.add_like('user1', 'Flying Machine Men Navy Blue Cap', 'Headwear', **input_params)
# - Flying Machine Men Red Cap (Red)
#   Score: 0.37
#   To like this item, use:
#   recommender.add_like('user1', 'Flying Machine Men Red Cap', 'Headwear', **input_params)
# - Flying Machine Men Red Cap (Red)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user1', 'Flying Machine Men Red Cap', 'Headwear', **input_params)
#
# Bottomwear:
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.29
#   To like this item, use:
#   recommender.add_like('user1', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.32
#   To like this item, use:
#   recommender.add_like('user1', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive  Men Blue Jeans (Blue)
#   Score: 0.28
#   To like this item, use:
#   recommender.add_like('user1', 'Locomotive  Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.29
#   To like this item, use:
#   recommender.add_like('user1', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
#
# Topwear:
# - Puma Men Navy Blue Polo T-shirt (Navy Blue)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user1', 'Puma Men Navy Blue Polo T-shirt', 'Topwear', **input_params)
# - Puma Men Navy Blue and White T-shirt (Navy Blue)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user1', 'Puma Men Navy Blue and White T-shirt', 'Topwear', **input_params)
# - Puma Men Navy Blue Polo T-shirt (Navy Blue)
#   Score: 0.43
#   To like this item, use:
#   recommender.add_like('user1', 'Puma Men Navy Blue Polo T-shirt', 'Topwear', **input_params)
# - ADIDAS Men Navy Blue & White Polo T-shirt (Navy Blue)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user1', 'ADIDAS Men Navy Blue & White Polo T-shirt', 'Topwear', **input_params)
#
# Flip Flops:
# - Lotto Men Navy Blue Flip Flops (Navy Blue)
#   Score: 0.34
#   To like this item, use:
#   recommender.add_like('user1', 'Lotto Men Navy Blue Flip Flops', 'Flip Flops', **input_params)
# - ADIDAS Men Navy Blue Flip Flops (Navy Blue)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user1', 'ADIDAS Men Navy Blue Flip Flops', 'Flip Flops', **input_params)
# - Lotto Men Grey Flip Flops (Grey)
#   Score: 0.34
#   To like this item, use:
#   recommender.add_like('user1', 'Lotto Men Grey Flip Flops', 'Flip Flops', **input_params)
# - ADIDAS Men Grey Flip Flops (Grey)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user1', 'ADIDAS Men Grey Flip Flops', 'Flip Flops', **input_params)
#
# Sandal:
# - Puma Men Black Sandals (Black)
#   Score: 0.44
#   To like this item, use:
#   recommender.add_like('user1', 'Puma Men Black Sandals', 'Sandal', **input_params)
# - Lotto Men Black Sandals (Black)
#   Score: 0.36
#   To like this item, use:
#   recommender.add_like('user1', 'Lotto Men Black Sandals', 'Sandal', **input_params)
# - Lotto Men Black Sandals (Black)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user1', 'Lotto Men Black Sandals', 'Sandal', **input_params)
# - Puma Men Black Sandals (Black)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user1', 'Puma Men Black Sandals', 'Sandal', **input_params)
#
# Shoes:
# - Nike Men Casual Navy Blue Shoes (Navy Blue)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user1', 'Nike Men Casual Navy Blue Shoes', 'Shoes', **input_params)
# - Numero Uno Men Navy Blue Casual Shoes (Navy Blue)
#   Score: 0.31
#   To like this item, use:
#   recommender.add_like('user1', 'Numero Uno Men Navy Blue Casual Shoes', 'Shoes', **input_params)
# - Vans Men Grey Casual Shoes (Grey)
#   Score: 0.37
#   To like this item, use:
#   recommender.add_like('user1', 'Vans Men Grey Casual Shoes', 'Shoes', **input_params)
# - Numero Uno Men Casual Navy Blue Shoes (Navy Blue)
#   Score: 0.33
#   To like this item, use:
#   recommender.add_like('user1', 'Numero Uno Men Casual Navy Blue Shoes', 'Shoes', **input_params)

# %%
recommender.add_like(
    user_id='user1',
    product_name='Flying Machine Men Red Cap',  # Nama produk langsung
    subcategory='Headwear',
    **input_params
)

# %%
outfit = recommender.get_complete_outfit('user2', **input_params)
print_outfit_recommendations(outfit, 'user2')
# Out:
# Recommendations for User user2:
# Input parameters: {'skin_tone': 'Fair', 'gender': 'Men', 'usage': 'Casual', 'season': 'Summer'}
#
# Recommended Colors: Navy Blue, Pink, Lavender, Purple, Blue, Teal, Burgundy, Red, White, Grey, Black, Turquoise Blue, Green, Sea Green
#
# Recommended Outfit:
#
# Accessories:
# - Cabarelli Men Accessory Gift Set (Black)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user2', 'Cabarelli Men Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Black Accessory Gift Set (Black)
#   Score: 0.33
#   To like this item, use:
#   recommender.add_like('user2', 'Cabarelli Men Black Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Accessory Gift Set (Black)
#   Score: 0.42
#   To like this item, use:
#   recommender.add_like('user2', 'Cabarelli Men Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Black Accessory Gift Set (Black)
#   Score: 0.35
#   To like this item, use:
#   recommender.add_like('user2', 'Cabarelli Men Black Accessory Gift Set', 'Accessories', **input_params)
#
# Headwear:
# - Flying Machine Men Red Cap (Red)
#   Score: 0.42
#   To like this item, use:
#   recommender.add_like('user2', 'Flying Machine Men Red Cap', 'Headwear', **input_params)
# - Flying Machine Men Navy Blue Cap (Navy Blue)
#   Score: 0.42
#   To like this item, use:
#   recommender.add_like('user2', 'Flying Machine Men Navy Blue Cap', 'Headwear', **input_params)
# - Flying Machine Men Green Cap (Green)
#   Score: 0.32
#   To like this item, use:
#   recommender.add_like('user2', 'Flying Machine Men Green Cap', 'Headwear', **input_params)
# - Flying Machine Men Red Cap (Red)
#   Score: 0.67
#   To like this item, use:
#   recommender.add_like('user2', 'Flying Machine Men Red Cap', 'Headwear', **input_params)
#
# Bottomwear:
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.31
#   To like this item, use:
#   recommender.add_like('user2', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive  Men Blue Jeans (Blue)
#   Score: 0.36
#   To like this item, use:
#   recommender.add_like('user2', 'Locomotive  Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.27
#   To like this item, use:
#   recommender.add_like('user2', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.27
#   To like this item, use:
#   recommender.add_like('user2', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
#
# Topwear:
# - Puma Men Navy Blue Polo T-shirt (Navy Blue)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user2', 'Puma Men Navy Blue Polo T-shirt', 'Topwear', **input_params)
# - Puma Men Navy Blue Polo T-shirt (Navy Blue)
#   Score: 0.42
#   To like this item, use:
#   recommender.add_like('user2', 'Puma Men Navy Blue Polo T-shirt', 'Topwear', **input_params)
# - ADIDAS Men Navy Blue & White Polo T-shirt (Navy Blue)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user2', 'ADIDAS Men Navy Blue & White Polo T-shirt', 'Topwear', **input_params)
# - Puma Men Navy Blue and White T-shirt (Navy Blue)
#   Score: 0.35
#   To like this item, use:
#   recommender.add_like('user2', 'Puma Men Navy Blue and White T-shirt', 'Topwear', **input_params)
#
# Flip Flops:
# - ADIDAS Men Grey Flip Flops (Grey)
#   Score: 0.41
#   To like this item, use:
#   recommender.add_like('user2', 'ADIDAS Men Grey Flip Flops', 'Flip Flops', **input_params)
# - ADIDAS Men Navy Blue Flip Flops (Navy Blue)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user2', 'ADIDAS Men Navy Blue Flip Flops', 'Flip Flops', **input_params)
# - Lotto Men Navy Blue Flip Flops (Navy Blue)
#   Score: 0.37
#   To like this item, use:
#   recommender.add_like('user2', 'Lotto Men Navy Blue Flip Flops', 'Flip Flops', **input_params)
# - Lotto Men Grey Flip Flops (Grey)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user2', 'Lotto Men Grey Flip Flops', 'Flip Flops', **input_params)
#
# Sandal:
# - Puma Men Black Sandals (Black)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user2', 'Puma Men Black Sandals', 'Sandal', **input_params)
# - Lotto Men Black Sandals (Black)
#   Score: 0.43
#   To like this item, use:
#   recommender.add_like('user2', 'Lotto Men Black Sandals', 'Sandal', **input_params)
# - Lotto Men Black Sandals (Black)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user2', 'Lotto Men Black Sandals', 'Sandal', **input_params)
# - Puma Men Black Sandals (Black)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user2', 'Puma Men Black Sandals', 'Sandal', **input_params)
#
# Shoes:
# - Nike Men Casual Navy Blue Shoes (Navy Blue)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user2', 'Nike Men Casual Navy Blue Shoes', 'Shoes', **input_params)
# - Numero Uno Men Casual Navy Blue Shoes (Navy Blue)
#   Score: 0.36
#   To like this item, use:
#   recommender.add_like('user2', 'Numero Uno Men Casual Navy Blue Shoes', 'Shoes', **input_params)
# - Vans Men Grey Casual Shoes (Grey)
#   Score: 0.33
#   To like this item, use:
#   recommender.add_like('user2', 'Vans Men Grey Casual Shoes', 'Shoes', **input_params)
# - Numero Uno Men Navy Blue Casual Shoes (Navy Blue)
#   Score: 0.35
#   To like this item, use:
#   recommender.add_like('user2', 'Numero Uno Men Navy Blue Casual Shoes', 'Shoes', **input_params)

# %%
recommender.add_like('user2', 'Flying Machine Men Red Cap', 'Headwear', **input_params)

# %%
outfit = recommender.get_complete_outfit('user3', **input_params)
print_outfit_recommendations(outfit, 'user3')
# Out:
# Recommendations for User user3:
# Input parameters: {'skin_tone': 'Fair', 'gender': 'Men', 'usage': 'Casual', 'season': 'Summer'}
#
# Recommended Colors: Navy Blue, Pink, Lavender, Purple, Blue, Teal, Burgundy, Red, White, Grey, Black, Turquoise Blue, Green, Sea Green
#
# Recommended Outfit:
#
# Accessories:
# - Cabarelli Men Accessory Gift Set (Black)
#   Score: 0.33
#   To like this item, use:
#   recommender.add_like('user3', 'Cabarelli Men Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Accessory Gift Set (Black)
#   Score: 0.35
#   To like this item, use:
#   recommender.add_like('user3', 'Cabarelli Men Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Black Accessory Gift Set (Black)
#   Score: 0.42
#   To like this item, use:
#   recommender.add_like('user3', 'Cabarelli Men Black Accessory Gift Set', 'Accessories', **input_params)
# - Cabarelli Men Black Accessory Gift Set (Black)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user3', 'Cabarelli Men Black Accessory Gift Set', 'Accessories', **input_params)
#
# Headwear:
# - Flying Machine Men Red Cap (Red)
#   Score: 0.40
#   To like this item, use:
#   recommender.add_like('user3', 'Flying Machine Men Red Cap', 'Headwear', **input_params)
# - Flying Machine Men Navy Blue Cap (Navy Blue)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user3', 'Flying Machine Men Navy Blue Cap', 'Headwear', **input_params)
# - Flying Machine Men Green Cap (Green)
#   Score: 0.35
#   To like this item, use:
#   recommender.add_like('user3', 'Flying Machine Men Green Cap', 'Headwear', **input_params)
# - Flying Machine Men Red Cap (Red)
#   Score: 0.72
#   To like this item, use:
#   recommender.add_like('user3', 'Flying Machine Men Red Cap', 'Headwear', **input_params)
#
# Bottomwear:
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.29
#   To like this item, use:
#   recommender.add_like('user3', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.34
#   To like this item, use:
#   recommender.add_like('user3', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive  Men Blue Jeans (Blue)
#   Score: 0.28
#   To like this item, use:
#   recommender.add_like('user3', 'Locomotive  Men Blue Jeans', 'Bottomwear', **input_params)
# - Locomotive Men Blue Jeans (Blue)
#   Score: 0.29
#   To like this item, use:
#   recommender.add_like('user3', 'Locomotive Men Blue Jeans', 'Bottomwear', **input_params)
#
# Topwear:
# - Puma Men Navy Blue Polo T-shirt (Navy Blue)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user3', 'Puma Men Navy Blue Polo T-shirt', 'Topwear', **input_params)
# - ADIDAS Men Navy Blue & White Polo T-shirt (Navy Blue)
#   Score: 0.37
#   To like this item, use:
#   recommender.add_like('user3', 'ADIDAS Men Navy Blue & White Polo T-shirt', 'Topwear', **input_params)
# - Puma Men Navy Blue Polo T-shirt (Navy Blue)
#   Score: 0.43
#   To like this item, use:
#   recommender.add_like('user3', 'Puma Men Navy Blue Polo T-shirt', 'Topwear', **input_params)
# - Puma Men Navy Blue and White T-shirt (Navy Blue)
#   Score: 0.36
#   To like this item, use:
#   recommender.add_like('user3', 'Puma Men Navy Blue and White T-shirt', 'Topwear', **input_params)
#
# Flip Flops:
# - ADIDAS Men Navy Blue Flip Flops (Navy Blue)
#   Score: 0.39
#   To like this item, use:
#   recommender.add_like('user3', 'ADIDAS Men Navy Blue Flip Flops', 'Flip Flops', **input_params)
# - ADIDAS Men Grey Flip Flops (Grey)
#   Score: 0.42
#   To like this item, use:
#   recommender.add_like('user3', 'ADIDAS Men Grey Flip Flops', 'Flip Flops', **input_params)
# - Lotto Men Grey Flip Flops (Grey)
#   Score: 0.38
#   To like this item, use:
#   recommender.add_like('user3', 'Lotto Men Grey Flip Flops', 'Flip Flops', **input_params)
# - Lotto Men Navy Blue Flip Flops (Navy Blue)
#   Score: 0.35
#   To like this item, use:
#   recommender.add_like('user3', 'Lotto Men Navy Blue Flip Flops', 'Flip Flops', **input_params)
#
# Sandal:
# - Puma Men Black Sandals (Black)
#   Score: 0.45
#   To like this item, use:
#   recommender.add_like('user3', 'Puma Men Black Sandals', 'Sandal', **input_params)
# - Lotto Men Black Sandals (Black)
#   Score: 0.37
#   To like this item, use:
#   recommender.add_like('user3', 'Lotto Men Black Sandals', 'Sandal', **input_params)
# - Puma Men Black Sandals (Black)
#   Score: 0.43
#   To like this item, use:
#   recommender.add_like('user3', 'Puma Men Black Sandals', 'Sandal', **input_params)
# - Lotto Men Black Sandals (Black)
#   Score: 0.37
#   To like this item, use:
#   recommender.add_like('user3', 'Lotto Men Black Sandals', 'Sandal', **input_params)
#
# Shoes:
# - Nike Men Casual Navy Blue Shoes (Navy Blue)
#   Score: 0.36
#   To like this item, use:
#   recommender.add_like('user3', 'Nike Men Casual Navy Blue Shoes', 'Shoes', **input_params)
# - Vans Men Grey Casual Shoes (Grey)
#   Score: 0.32
#   To like this item, use:
#   recommender.add_like('user3', 'Vans Men Grey Casual Shoes', 'Shoes', **input_params)
# - Numero Uno Men Casual Navy Blue Shoes (Navy Blue)
#   Score: 0.31
#   To like this item, use:
#   recommender.add_like('user3', 'Numero Uno Men Casual Navy Blue Shoes', 'Shoes', **input_params)
# - Numero Uno Men Navy Blue Casual Shoes (Navy Blue)
#   Score: 0.32
#   To like this item, use:
#   recommender.add_like('user3', 'Numero Uno Men Navy Blue Casual Shoes', 'Shoes', **input_params)
